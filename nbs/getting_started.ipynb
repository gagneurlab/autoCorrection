# %%
# %matplotlib inline

# %%
from autoCorrection.data_utils import DataReader, Evaluation
# Out:
# Using TensorFlow backend.

# %%
from autoCorrection.correctors import AECorrector

# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data:

# %%
dr = DataReader()

# %% [markdown]
# Skin tissue:

# %%
data = dr.read_gtex_skin()

# %% [markdown]
# or blood tissue:

# %%
#data = dr.read_gtex_blood()

# %%
data.shape
# Out:
# (258, 16530)

# %% [markdown]
# ## Correct:

# %%
corrected = AECorrector().correct(data)
# Out:
# Preparing data!
# Using OutInjectionFC method!
# Injecting!
# Train on 351 samples, validate on 40 samples
# Epoch 1/250
# 351/351 [==============================] - 0s - loss: 420.6063 - val_loss: 120.4832
# Epoch 2/250
# 351/351 [==============================] - 0s - loss: 69.1437 - val_loss: 36.6417
# Epoch 3/250
# 351/351 [==============================] - 0s - loss: 30.5399 - val_loss: 26.6504
# Epoch 4/250
# 351/351 [==============================] - 0s - loss: 22.1891 - val_loss: 20.1470
# Epoch 5/250
# 351/351 [==============================] - 0s - loss: 17.8538 - val_loss: 17.4978
# Epoch 6/250
# 351/351 [==============================] - 0s - loss: 15.9277 - val_loss: 16.0567
# Epoch 7/250
# 351/351 [==============================] - 0s - loss: 14.8255 - val_loss: 15.1391
# Epoch 8/250
# 351/351 [==============================] - 0s - loss: 14.0254 - val_loss: 14.4574
# Epoch 9/250
# 351/351 [==============================] - 0s - loss: 13.4318 - val_loss: 13.9144
# ...

# %% [markdown]
# ## Evaluate:

# %%
ev = Evaluation(data, corrected)

# %%
ev.plot_correlations_of_samples()

# %% [markdown]
# ----

# %% [markdown]
# ----

# %% [markdown]
# ## Different tissues

# %%
data = dr.read_gtex_several_tissues()

# %%
data.shape
# Out:
# (595, 11908)

# %%
corrected = AECorrector().correct(data)
# Out:
# Preparing data!
# Using OutInjectionFC method!
# Injecting!
# Train on 535 samples, validate on 60 samples
# Epoch 1/250
# 535/535 [==============================] - 0s - loss: 63.3821 - val_loss: 28.6947
# Epoch 2/250
# 535/535 [==============================] - 0s - loss: 22.3676 - val_loss: 19.1145
# Epoch 3/250
# 535/535 [==============================] - 0s - loss: 17.1653 - val_loss: 16.2806
# Epoch 4/250
# 535/535 [==============================] - 0s - loss: 15.0166 - val_loss: 14.7872
# Epoch 5/250
# 535/535 [==============================] - 0s - loss: 13.6621 - val_loss: 13.7641
# Epoch 6/250
# 535/535 [==============================] - 0s - loss: 12.6200 - val_loss: 12.8945
# Epoch 7/250
# 535/535 [==============================] - 0s - loss: 11.8193 - val_loss: 12.1385
# Epoch 8/250
# 535/535 [==============================] - 0s - loss: 11.2506 - val_loss: 11.7444
# Epoch 9/250
# 535/535 [==============================] - 0s - loss: 10.7978 - val_loss: 11.2579
# ...

# %%
ev = Evaluation(data, corrected)

# %%
ev.plot_correlations_of_samples()

# %% [markdown]
# -----

# %% [markdown]
# ----

# %% [markdown]
# ## Small data

# %%
data = dr.read_skin_small()

# %%
data.shape
# Out:
# (100, 1000)

# %%
corrected = AECorrector().correct(data)
# Out:
# Preparing data!
# Using OutInjectionFC method!
# Injecting!
# Train on 90 samples, validate on 10 samples
# Epoch 1/250
# 90/90 [==============================] - 0s - loss: 200.0397 - val_loss: 82.9458
# Epoch 2/250
# 90/90 [==============================] - 0s - loss: 78.2579 - val_loss: 66.4086
# Epoch 3/250
# 90/90 [==============================] - 0s - loss: 73.0108 - val_loss: 65.1731
# Epoch 4/250
# 90/90 [==============================] - 0s - loss: 71.9098 - val_loss: 58.0634
# Epoch 5/250
# 90/90 [==============================] - 0s - loss: 61.5077 - val_loss: 52.0792
# Epoch 6/250
# 90/90 [==============================] - 0s - loss: 53.8154 - val_loss: 48.1302
# Epoch 7/250
# 90/90 [==============================] - 0s - loss: 48.3388 - val_loss: 44.7522
# Epoch 8/250
# 90/90 [==============================] - 0s - loss: 43.3046 - val_loss: 41.3924
# Epoch 9/250
# 90/90 [==============================] - 0s - loss: 39.1540 - val_loss: 37.9357
# Epoch 10/250
# ...

# %%
ev = Evaluation(data, corrected)

# %%
ev.plot_correlations_of_samples()

# %% [markdown]
# ---

# %% [markdown]
# ----

# %% [markdown]
# ## Prediction using saved model

# %% [markdown]
# Specifying corrector with model name (default name:"model"):

# %%
corrector = AECorrector(model_name="my_model1")

# %% [markdown]
# Training and saving the model:

# %%
corrected = corrector.correct(data)
# Out:
# Preparing data!
# Using OutInjectionFC method!
# Injecting!
# Train on 90 samples, validate on 10 samples
# Epoch 1/250
# 90/90 [==============================] - 0s - loss: 415.4337 - val_loss: 166.5763
# Epoch 2/250
# 90/90 [==============================] - 0s - loss: 143.1858 - val_loss: 94.8942
# Epoch 3/250
# 90/90 [==============================] - 0s - loss: 87.8773 - val_loss: 70.7584
# Epoch 4/250
# 90/90 [==============================] - 0s - loss: 71.3292 - val_loss: 59.5299
# Epoch 5/250
# 90/90 [==============================] - 0s - loss: 64.0947 - val_loss: 52.7745
# Epoch 6/250
# 90/90 [==============================] - 0s - loss: 58.6165 - val_loss: 47.6833
# Epoch 7/250
# 90/90 [==============================] - 0s - loss: 53.4273 - val_loss: 43.3352
# Epoch 8/250
# 90/90 [==============================] - 0s - loss: 48.0367 - val_loss: 39.3816
# Epoch 9/250
# 90/90 [==============================] - 0s - loss: 42.5521 - val_loss: 35.7677
# Epoch 10/250
# ...

# %% [markdown]
# Only predicting, using model "my_model1" saved on disk:

# %%
corrected = corrector.correct(data,only_predict=True)
# Out:
# Preparing data!
# Model loaded from disk!

# %%
ev = Evaluation(data, corrected)

# %%
ev.plot_correlations_of_samples()
