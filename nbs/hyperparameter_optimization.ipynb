# %%
from autoCorrection import optimization
# Out:
# Using TensorFlow backend.

# %% [markdown]
#  ### Run locally

# %%
opt = optimization.Optimization(nr_of_trials=1)
opt()
# Out:
# 2018-03-20 16:57:34,928 [INFO] tpe_transform took 0.005603 seconds
# 2018-03-20 16:57:34,929 [INFO] TPE using 0 trials
# 2018-03-20 16:57:34,988 [INFO] Load data...
# ----------------------------------------
# exp_name: exp1
# Using OutInjectionFC method!
# Injecting!
# Using OutInjectionFC method!
# Injecting!
# 2018-03-20 16:57:43,917 [INFO] Fit...
# ['loss']
# Train on 232 samples, validate on 26 samples
# Epoch 1/500
# 0s - loss: 350.2186 - val_loss: 96.0172
# Epoch 2/500
# 0s - loss: 109.2254 - val_loss: 75.3205
# Epoch 3/500
# 0s - loss: 57.7371 - val_loss: 40.2189
# Epoch 4/500
# 0s - loss: 39.7866 - val_loss: 44.8566
# Epoch 5/500
# 0s - loss: 43.2721 - val_loss: 41.1992
# Epoch 6/500
# 0s - loss: 39.0369 - val_loss: 36.8140
# Epoch 7/500
# 0s - loss: 34.7756 - val_loss: 32.2562
# Epoch 8/500
# 0s - loss: 30.5225 - val_loss: 28.8863
# Epoch 9/500
# 0s - loss: 27.2927 - val_loss: 25.5846
# Epoch 10/500
# 0s - loss: 24.4195 - val_loss: 24.0738
# Epoch 11/500
# ...

# %% [markdown]
# ### Run on mongoDB, starting mongoDB and workers from autoCorrect

# %%
opt = optimization.Optimization(run_on_mongodb=True, start_mongodb=True,
                                nr_of_trials=2, exp_name="noname")
opt()
# Out:
# 2018-03-20 17:03:42,065 [INFO] PROTOCOL mongo
# 2018-03-20 17:03:42,067 [INFO] USERNAME None
# 2018-03-20 17:03:42,068 [INFO] HOSTNAME localhost
# 2018-03-20 17:03:42,069 [INFO] PORT 22334
# 2018-03-20 17:03:42,070 [INFO] PATH /corrector/jobs
# 2018-03-20 17:03:42,071 [INFO] DB corrector
# 2018-03-20 17:03:42,072 [INFO] COLLECTION jobs
# 2018-03-20 17:03:42,073 [INFO] PASS None
# 2018-03-20 17:03:42,112 [INFO] tpe_transform took 0.006192 seconds
# 2018-03-20 17:03:42,113 [INFO] TPE using 0 trials
# ----------------------------------------
# exp_name: noname
# starting mongod ['mongod', '--dbpath=/scratch/tmp/tmpppsqzjmv', '--noprealloc', '--port=22334']
# 2018-03-20 17:03:44,141 [INFO] tpe_transform took 0.005623 seconds
# 2018-03-20 17:03:44,142 [INFO] TPE using 1/1 trials with best loss inf
# 2018-03-20 17:03:45,156 [INFO] Waiting for 2 jobs to finish ...
# 2018-03-20 17:06:54,323 [INFO] Queue empty, exiting run.
# ----------------------------------------------------
# ...
